# %%
import pandas as pd

# %%
train = pd.read_csv('/Applications/Projects/Bladder Research/Data/data/train.csv')
test = pd.read_csv('/Applications/Projects/Bladder Research/Data/data/test.csv')
valid = pd.read_csv('/Applications/Projects/Bladder Research/Data/data/valid.csv')

# %%
len(train), len(valid), len(test)
# Out:
# (1224, 304, 189)

# %%
total = len(train) + len(valid) + len(test)
print(f'Training set: {len(train)} images ({len(train)/total:.2%})')
print(f'Validation set: {len(valid)} images ({len(valid)/total:.2%})')
print(f'Test set: {len(test)} images ({len(test)/total:.2%})')
# Out:
# Training set: 1224 images (71.29%)
# Validation set: 304 images (17.71%)
# Test set: 189 images (11.01%)

# %%
round(train['tissue type'].value_counts(normalize=True) * 100, 2)
# Out:
# tissue type
# LGC    39.38
# NST    28.27
# HGC    25.25
# NTL     7.11
# Name: proportion, dtype: float64

# %%
round(test['tissue type'].value_counts(normalize=True) * 100, 2)
# Out:
# tissue type
# HGC    39.15
# LGC    28.04
# NST    19.58
# NTL    13.23
# Name: proportion, dtype: float64

# %%
round(valid['tissue type'].value_counts(normalize=True) * 100, 2)
# Out:
# tissue type
# LGC    36.84
# HGC    28.29
# NST    27.63
# NTL     7.24
# Name: proportion, dtype: float64
