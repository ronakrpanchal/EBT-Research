# %%
import pandas as pd

# %%
aani = pd.read_csv('/Applications/Projects/Bladder Research/Output/aani_combined_output.csv')
naai = pd.read_csv('/Applications/Projects/Bladder Research/Output/naai_combined_output.csv')
nawi = pd.read_csv('/Applications/Projects/Bladder Research/Output/nawi_combined_output.csv')

# %%
aani['Overall_Accuracy'].mean(), naai['Overall_Accuracy'].mean(), nawi['Overall_Accuracy'].mean()
# Out:
# (43.98148148148149, 39.704585537918874, 38.64638447971782)
